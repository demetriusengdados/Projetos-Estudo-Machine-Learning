# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# ##<font color='GreeN'>Dicas e Truques de Ciência de Dados </font>
#
# ##<font color='grey'>Aprendizado de Máquina</font>
#
# # <font color='black'>Aprendizagem Supervisionada - Resolvendo Problemas de Classificação</font>

# %%
# Importação de Bibliotecas Necessárias 
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 1° Definir o Problema de Negócio

# %% [markdown]
# Precisamos Criar uma Máquina Preditiva que detecte qual é o Tipo de Flor(setosa, virginica, versicolor ), dadas as características das Petalas (largura-width e comprimento-length) e das Sepalas.

# %%
# IRIS dataset
from PIL import Image
# %matplotlib inline
im = Image.open("iris.JPG")
im.show()
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=513x237 at 0x7F1309165B00>

# %% [markdown]
# # 2° Análise Exploratória dos dados

# %%
#Carregando o Iris dataset
iris = load_iris()

# %%
#Conhecendo os Atributos do Dataset
#Descrição
iris.DESCR

# %%
#Variáveis (features_names)
iris.feature_names

# %%
iris.target

# %%
iris.target_names

# %%
#Domínios da Variável Target -3 Espécies de flores.
y_names = iris.target_names
y_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# # 3° Pré-Processamento dos dados

# %%
# Separando Variáveis Explicaticas e Target
x = iris.data #array de variáveis explicativas
y = iris.target #array de labels (Target, variável a ser explicada...)

# %%
# Dividindo os dados em Treino e Teste (30% para teste)
X_train,  X_test,  Y_train, Y_test, = train_test_split(x, y, test_size=0.3)

# %% [markdown]
# # 4° Criando a Máquina Preditiva

# %%
#Machine Learning - Problemas de Classificação - Algoritmo "Decision Tree" ou Árvores de Decisão 
#maquina_preditiva = tree.DecisionTreeClassifier()
maquina_preditiva = RandomForestClassifier(n_estimators=1000)

#OBS: Decision Tree acertou 95.55%
#OBS: Random Forest acertou 95.55%

# %%
#Treinando (training-fitting) o Algoritmo (Nossa Máquina Preditiva) com os dados de Treino
maquina_preditiva.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Testando a Máquina Preditiva com os Dados de Teste
Valor_predito = maquina_preditiva.predict(X_test)
print(Valor_predito)
# Out:
# [1 1 1 0 2 0 1 2 1 1 2 1 0 2 0 0 0 0 2 2 2 0 0 1 0 1 1 2 1 2 1 0 0 2 2 2 1
#  1 2 2 0 1 2 2 2]

# %% [markdown]
# # 5° Avaliando a Acurácia do Modelo de Machine Learning

# %%
#Avaliando a Acurácia da Máquina Preditiva
print(((accuracy_score(Valor_predito, Y_test)))*100)

# %% [markdown]
# # Valeu Demais!

# %% [markdown]
# ### #Instagram - Ciencia dos Dados <a href="http://instagram.com/cienciadosdados">instagram.com/cienciadosdados</a>

# %% [markdown]
# ### #**Telegram** - Scripts e Datasets - Comunidade Telegram <a href="https://t.me/cienciadosdadosraiz">https://t.me/cienciadosdadosraiz</a>

# %% [markdown]
# ### #Facebook - Ciencia dos Dados <a href="http://facebook.com/cienciadosdadosbr">facebook.com/cienciadosdadosbr</a>

# %% [markdown]
# ### #YouTube - Mais Aulas como essa no YouTube <a href="https://www.youtube.com/watch?v=IaIc5oHd3II&t=1569s">https://www.youtube.com/watch?v=IaIc5oHd3II&t=1569s</a>

# %% [markdown]
# ### #Portal Gratuito - Ciencia dos Dados <a href="http://cienciadosdados.com">cienciadosdados.com</a>

# %%
from IPython.core.display import HTML
HTML('<iframe width="380" height="200" src="https://www.youtube.com/embed/U7VJljqHwjY?list=PLeR2Gm6UuDXr14EhmTpJ9kdqgG0z2YB-w" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="380" height="200" src="https://www.youtube.com/embed/U7VJljqHwjY?list=PLeR2Gm6UuDXr14EhmTpJ9kdqgG0z2YB-w" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
